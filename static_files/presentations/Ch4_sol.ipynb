# %% [markdown]
# # Exercise 4

# %% [markdown]
# ### (1) A linked list is a good structure candidate for a list because:

# %% [markdown]
# (A) It does not use much memory space.
#
# (B) It is fast to traverse.
#
# (C) Its implementation can be easily translated into machine code.
#
# (D) Once the relevant node or predecessor is known, insertion or deletion can be done by relinking pointers without shifting later elements.

# %% [markdown]
# (D)

# %% [markdown]
# ### (2) In a linked list, each element(node) contains _______
#
# (A) only data
#
# (B) data and reference (pointer)
#
# (C) only reference (pointer)
#
# (D) None of above

# %% [markdown]
# (B)

# %% [markdown]
# ### (3) Select the correct statement below.

# %% [markdown]
# (A) Every Node is contained within the `UnorderedList` class object. Making access to every Node of the linked list possible.
#
# (B) Every Node in the linked list is exactly one space in memory away from the next. Making it possible to find the next Node and traverse through the list.
#
# (C) Every Node in the list is in various locations in memory, and those memory addresses are stored in an array inside of the `UnorderedList` object, which makes accessing each Node possible.
#
# (D) Every Node in the list is in various locations in memory, and each Node contains a reference to the next Node in the list without needing to be contained in the `UnorderedList` class.

# %% [markdown]
# (D)

# %% [markdown]
# ### (4-1) In C++, which of the following indicates a linked list with one item?

# %% [markdown]
# (A) `header != NULL`
#
# (B) `header == NULL`
#
# (C) `header != NULL && header->getNext() == NULL`
#
# (D) `header != NULL && header->getNext() != NULL && header->getNext()->getNext() != NULL`

# %% [markdown]
# (C)

# %% [markdown]
# ### (4-2) In Python, which of the following indicates a linked list with one item?

# %% [markdown]
# (A) `header is not None`
#
# (B) `header is None`
#
# (C) `header is not None and header.next is None`
#
# (D) `header is not None and header.next is not None and header.next.next is not None`

# %% [markdown]
# (C)

# %% [markdown]
# ### (5) Compare the advantages and costs of unordered and ordered linked lists.

# %% [markdown]
# Ans:
#
# An unordered linked list can insert at the head in $O(1)$ time. Searching for a value and removing by value are $O(n)$ in the worst case because the list may need a full traversal. Once the target and its predecessor are already known, unlinking the node itself is $O(1)$.
#
# An ordered linked list preserves sorted order. Search may stop early after passing the target, but its worst-case complexity is still $O(n)$; it is not binary search because linked lists lack constant-time random access. Insertion is $O(n)$ overall when the insertion position must first be found, followed by an $O(1)$ relink.

# %% [markdown]
# ### (6) Compare the advantages and costs of singly and doubly linked lists.

# %% [markdown]
# Ans:
# A normal (singly) linked list is simpler and uses less memory per node since each node only stores a reference to the next node. This makes it efficient for memory usage and straightforward operations like insertion and deletion at the beginning of the list. However, it lacks the ability to traverse backwards, making operations that require reverse traversal or deletion from the end less efficient, as you have to iterate from the head to get to the previous node.
#
# Doubly linked lists, conversely, allow for traversal in both directions thanks to an extra pointer in each node pointing to the previous node. This added functionality facilitates operations like reverse traversal and efficient deletion from both ends but comes at the cost of increased memory usage per node and slightly more complex insertion and deletion operations, as two pointers need to be updated instead of one.
