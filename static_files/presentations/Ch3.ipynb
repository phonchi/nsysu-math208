# %% [markdown]
# # Exercise 3

# %% [markdown]
# ### (1) If the two-dimensional array X were stored in column-major order, then in the block of main memory containing X, which of the following would be true?

# %% [markdown]
# (A) The entry `X[1,2]` would appear before `X[2,1]`.
#
# (B) The entry `X[3,3]` would appear before `X[2,4]`.
#
# (C) The entry `X[3,2]` would appear after `X[2,3]`.
#
# (D) The entry `X[1,2]` would be in the same location as `X[2,1]`.

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (2) When you try to calculate the location of an entry in a two-dimensional array in main memory, which of the following is not used in the calculation? Assuming that it stores the array in column-major order.

# %% [markdown]
# (A) Number of rows in the array.
#
# (B) The starting address of the first element.
#
# (C) The row number of the element.
#
# (D) Number of columns in the array.

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (3) `A` is a two dimensional array, the location of `A[3,2]` is 1110 and `A[2,3]` is 1115. Assume that each element occupies one address, and the size of `A` is $m \times n$, then (Assume the starting index is (1,1) instead of (0,0))
#
# (A) The location of `A[1,4]` is 1120.
#
# (B) `m, n` must be less then 8.
#
# (C) The location of `A[5,4]` is 1134.
#
# (D) The value of `m` is 7.

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (4) Which of the following statements is true regarding the storage of arrays and sparse matrices?
#
# (A) Compact arrays are the most memory-efficient way to store sparse matrices due to their simplicity.
#
# (B) Sparse matrices are typically stored using compact arrays to enhance computational performance.
#
# (C) Specialized storage schemes like COOrdinate (COO) format are not suitable for sparse matrices as they increase memory usage.
#
# (D) Sparse matrices utilize specialized storage schemes, such as COOrdinate (COO) format, to save memory by only storing non-zero elements and their positions.

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (5) What is a Sparse Matrix and why we do not use compact array to store it?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (6) What is the Big O complexity to remove an element from an array?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (7) We have stored the two-dimensional array students in the memory. The array is 10 × 50 (10 rows and 50 columns). Show the address of the element `students[5][3]` assuming that the element `student[0][0]` is stored in the memory location with address 10 and each element occupies only one memory location. The computer uses column-major storage.

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (8) What is COOrdinate (COO) format?

# %% [markdown]
# > Ans: *Double click to answer the question*
